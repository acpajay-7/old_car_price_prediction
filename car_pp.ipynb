# %%
import pandas as pd



df = pd.read_csv('data\car_price.csv')
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# <>:5: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\ajayp\AppData\Local\Temp\ipykernel_24048\306245042.py:5: SyntaxWarning: invalid escape sequence '\c'
#   df = pd.read_csv('data\car_price.csv')
#     Brand  Year  Kilometers_Driven Fuel_Type Transmission  Engine_CC  \
# 0     Kia  2012              84148    Diesel    Automatic     2444.0
# 1  Toyota  2026              88186    Petrol       Manual     1075.0
# 2    Ford  2019             156094       CNG    Automatic     1896.0
# 3    Tata  2023             128629    Diesel    Automatic     2502.0
# 4     Kia  2022              75316    Diesel       Manual     2595.0
#
#    Mileage_kmpl  Seats  Owner_Count  Selling_Price
# 0          17.4      5            4        1591000
# 1          25.8      5            1        2669000
# 2          17.7      7            1        2061000
# 3          25.8      7            1        3073000
# 4          22.1      7            1        3150000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1000 non-null   str
#  1   Year               1000 non-null   int64
#  2   Kilometers_Driven  1000 non-null   int64
#  3   Fuel_Type          995 non-null    str
#  4   Transmission       1000 non-null   str
#  5   Engine_CC          995 non-null    float64
#  6   Mileage_kmpl       995 non-null    float64
#  7   Seats              1000 non-null   int64
#  8   Owner_Count        1000 non-null   int64
#  9   Selling_Price      1000 non-null   int64
# dtypes: float64(2), int64(5), str(3)
# memory usage: 78.3 KB

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven    Engine_CC  Mileage_kmpl        Seats  \
# count  1000.000000         1000.00000   995.000000    995.000000  1000.000000
# mean   2019.020000        83184.58700  1729.667337     17.940201     5.654000
# std       4.349082        45613.04083   525.363956      4.622347     1.051375
# min    2012.000000         5155.00000   800.000000     10.000000     4.000000
# 25%    2015.000000        41459.75000  1248.500000     14.000000     5.000000
# 50%    2019.000000        83764.50000  1750.000000     17.700000     5.000000
# 75%    2023.000000       123623.75000  2202.000000     21.950000     7.000000
# max    2026.000000       159983.00000  2599.000000     26.000000     8.000000
#
#        Owner_Count  Selling_Price
# count   1000.00000   1.000000e+03
# mean       1.53700   2.093748e+06
# std        0.78182   5.571430e+05
# min        1.00000   6.800000e+05
# 25%        1.00000   1.699750e+06
# 50%        1.00000   2.101500e+06
# 75%        2.00000   2.518250e+06
# max        4.00000   3.457000e+06

# %%
df.isnull().sum()
# Out:
# Brand                0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            5
# Transmission         0
# Engine_CC            5
# Mileage_kmpl         5
# Seats                0
# Owner_Count          0
# Selling_Price        0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#         Brand  Year  Kilometers_Driven Fuel_Type Transmission  Engine_CC  \
# 55     Toyota  2021              69324       CNG    Automatic     2266.0
# 87     Maruti  2026              76635       NaN    Automatic     2261.0
# 123       Kia  2025              84141       NaN    Automatic     2382.0
# 125    Toyota  2014              44062       NaN       Manual     1375.0
# 298     Honda  2024              36007       NaN       Manual      996.0
# 433     Honda  2020             102033    Petrol       Manual        NaN
# 494      Tata  2022             150128    Petrol       Manual     2166.0
# 577     Honda  2021              97949    Diesel       Manual        NaN
# 589      Tata  2012              81272       NaN       Manual     2262.0
# 608  Mahindra  2019              69028    Diesel       Manual        NaN
# 660      Tata  2014              87617    Petrol       Manual        NaN
# 714       Kia  2018              38787    Petrol       Manual        NaN
# 846      Tata  2012              75202    Petrol    Automatic     2325.0
# 871    Maruti  2012             105417    Petrol       Manual     1580.0
# 897      Ford  2026             143043    Petrol       Manual     2391.0
#
#      Mileage_kmpl  Seats  Owner_Count  Selling_Price
# 55            NaN      5            2        2611000
# 87           16.3      5            1        3145000
# 123          17.5      5            1        3181000
# 125          12.9      8            1        1705000
# 298          17.0      5            2        2363000
# 433          21.2      5            1        2110000
# 494           NaN      5            1        2506000
# 577          25.1      7            1        2530000
# 589          14.1      8            1        1408000
# 608          19.8      5            1        2038000
# 660          17.9      7            1        1587000
# 714          11.0      5            3        1627000
# 846           NaN      5            1        1483000
# 871           NaN      7            2        1199000
# 897           NaN      5            2        2635000

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 985 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              985 non-null    str
#  1   Year               985 non-null    int64
#  2   Kilometers_Driven  985 non-null    int64
#  3   Fuel_Type          985 non-null    str
#  4   Transmission       985 non-null    str
#  5   Engine_CC          985 non-null    float64
#  6   Mileage_kmpl       985 non-null    float64
#  7   Seats              985 non-null    int64
#  8   Owner_Count        985 non-null    int64
#  9   Selling_Price      985 non-null    int64
# dtypes: float64(2), int64(5), str(3)
# memory usage: 84.6 KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df["Selling_Price"],kde=True)
plt.title("Distribution of Car Selling Price")
plt.xlabel("Selling Price")
plt.ylabel("Number of Cars")

plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(data=df,x="Year",y="Selling_Price")
plt.title("Car Year vs Selling Price")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=df,x="Fuel_Type",y="Selling_Price")
plt.title("Selling Price by Fuel Type")

plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)
numeric_df.head()
# Out:
#    Year  Kilometers_Driven  Engine_CC  Mileage_kmpl  Seats  Owner_Count  \
# 0  2012              84148     2444.0          17.4      5            4
# 1  2026              88186     1075.0          25.8      5            1
# 2  2019             156094     1896.0          17.7      7            1
# 3  2023             128629     2502.0          25.8      7            1
# 4  2022              75316     2595.0          22.1      7            1
#
#    Selling_Price
# 0        1591000
# 1        2669000
# 2        2061000
# 3        3073000
# 4        3150000

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(numeric_df.corr(),annot=True)
plt.title("Correlation heatmap")
plt.show()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
numeric_features = [
    "Year",
    "Kilometers_Driven",
    "Engine_CC",
    "Mileage_kmpl",
    "Seats",
    "Owner_Count",
    "Car_Age",
    "Km_Per_Year"
]

categorical_features = [
    "Brand",
    "Fuel_Type",
    "Transmission"
]

# %%
numeric_transformer = Pipeline(
    steps=[("imputer",SimpleImputer(strategy="median"))]
    )

# %%
categorical_transformer = Pipeline(
    steps=[("imputer",SimpleImputer(strategy="most_frequent")),
        ("encoder",OneHotEncoder(handle_unknown="ignore",drop="first"))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[("num",numeric_transformer,numeric_features),
     ( "cat",categorical_transformer,categorical_features)
    ]
)

# %%
CURRENT_YEAR = 2026
df["Car_Age"] = CURRENT_YEAR - df["Year"]
df["Km_Per_Year"] = (df["Kilometers_Driven"] /df["Car_Age"].replace(0, 1))

X = df.drop("Selling_Price", axis=1)

Y = df["Selling_Price"]

# %%
# X = pd.get_dummies(X,columns=["Brand", "Fuel_Type", "Transmission"],drop_first=True)
# X.info()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# %%
rf_pipeline = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "model",
            rf_model
        )
    ]
)

# %%
rf_pipeline.fit(
    X_train,
    Y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Year', 'Kilometers_Driven',
#                                                    'Engine_CC', 'Mileage_kmpl',
#                                                    'Seats', 'Owner_Count',
#                                                    'Car_Age', 'Km_Per_Year']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['Brand', 'Fuel_Type',
#                                                    'Transmission'])])),
#                 ('model',
#                  RandomForestRegressor(n_estimators=200, n_jobs=-1,
#                                        random_state=42))])

# %%
Y_predict = rf_pipeline.predict(X_test)

# %%
print(Y_predict[:10])
# Out:
# [2603010. 2509305. 1406285. 2757600. 1719075. 1825095. 1180030. 1517010.
#  1743410. 3069170.]

# %%
mae = mean_absolute_error(Y_test, Y_predict)

print("MAE:", mae)
# Out:
# MAE: 148382.34662576686

# %%
rmse = np.sqrt(
    mean_squared_error(Y_test, Y_predict))

print(f"RMSE: ₹{rmse:,.2f}")
# Out:
# RMSE: ₹182,754.21

# %%
r2 = r2_score(Y_test, Y_predict)

print("R² Score:", r2)
# Out:
# R² Score: 0.881856260275734

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(
    Y_test,
    Y_predict
)

print(f"MAE: ₹{mae:,.2f}")
# Out:
# MAE: ₹148,382.35

# %%
final_model = rf_pipeline

# %%
plt.figure(figsize=(8, 6))

plt.scatter(Y_test,Y_predict,alpha=0.6)

plt.xlabel("Actual Selling Price")
plt.ylabel("Predicted Selling Price")

plt.title("Actual vs Predicted Car Prices")

plt.plot(
    [Y_test.min(), Y_test.max()],
    [Y_test.min(), Y_test.max()],
    linestyle="--"
)

plt.show()

# %%
residuals = Y_test - Y_predict
plt.figure(figsize=(8, 6))

plt.scatter(Y_predict, residuals, alpha=0.6)

plt.axhline( y=0, linestyle="--")

plt.xlabel("Predicted Price")
plt.ylabel("Residual")

plt.title("Residual Analysis")
plt.show()

# %%
feature_names = (rf_pipeline.named_steps["preprocessor"].get_feature_names_out()
)
importances = (rf_pipeline.named_steps["model"].feature_importances_
)
feature_importance = pd.DataFrame({"Feature": feature_names,"Importance": importances})

feature_importance = (feature_importance.sort_values( "Importance", ascending=False))

feature_importance.head(15)
# Out:
#                      Feature  Importance
# 6               num__Car_Age    0.367022
# 0                  num__Year    0.339059
# 2             num__Engine_CC    0.192372
# 3          num__Mileage_kmpl    0.025731
# 1     num__Kilometers_Driven    0.025626
# 7           num__Km_Per_Year    0.011961
# 5           num__Owner_Count    0.007546
# 20  cat__Transmission_Manual    0.007531
# 4                 num__Seats    0.004546
# 19     cat__Fuel_Type_Petrol    0.002781
# 15         cat__Brand_Toyota    0.002470
# 18   cat__Fuel_Type_Electric    0.002173
# 9         cat__Brand_Hyundai    0.001566
# 17     cat__Fuel_Type_Diesel    0.001562
# 14           cat__Brand_Tata    0.001454

# %%
plt.figure(figsize=(10, 6))

feature_importance.head(10).sort_values("Importance").plot(
    x="Feature",
    y="Importance",
    kind="barh",
    legend=False
)

plt.title("Top 10 Features Affecting Car Price")

plt.xlabel("Importance")

plt.show()

# %%
import joblib

joblib.dump(
    final_model,
    "car_price_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!
